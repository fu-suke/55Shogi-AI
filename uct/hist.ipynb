# %%
import matplotlib.pyplot as plt
scores = []
with open("random_playout_results.txt", "r") as file:
    for line in file:
        scores.append(float(line.strip()))

plt.hist(scores, bins=50)
plt.title("Playout Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()
mean = sum(scores) / len(scores) 
print("平均値: {}".format(mean))
# Out:
# 平均値: 0.48244072805558014

# %%
import matplotlib.pyplot as plt

# ファイルからスコアを読み込む
scores = []
with open("capture_playout_results.txt", "r") as file:
    for line in file:
        scores.append(float(line.strip()))

# ヒストグラムを作成
plt.hist(scores, bins=50)  # ビンの数は必要に応じて調整
plt.title("Playout Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# 平均値を計算
mean = sum(scores) / len(scores)
print("平均値: {}".format(mean))
# Out:
# 平均値: 0.4574680190904713

# %%
import matplotlib.pyplot as plt

"""
**********
r_b_____k_
____s_g___
P_______p_
__G_S_____
K_____B_R_
**********
"""

# ファイルからスコアを読み込む
scores = []
with open("random_playout_results.txt", "r") as file:
    for line in file:
        scores.append(float(line.strip()))

# ヒストグラムを作成
plt.hist(scores, bins=50)  # ビンの数は必要に応じて調整
plt.title("Playout Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# 平均値を計算
mean = sum(scores) / len(scores)
print("平均値: {}".format(mean))  # 平均値: 0.48558810710834427
# 0.4297710817141529
# Out:
# 平均値: 0.48558810710834427

# %%
import matplotlib.pyplot as plt

"""
**********
r_b_____k_
______g___
P_G_____p_
__________
K_____B_R_
**********
BLACK: hand: 0P1S0G0B0R

WHITE: hand: 0P1S0G0B0R
"""

# ファイルからスコアを読み込む
scores = []
with open("random_playout_results.txt", "r") as file:
    for line in file:
        scores.append(float(line.strip()))

# ヒストグラムを作成
plt.hist(scores, bins=50)  # ビンの数は必要に応じて調整
plt.title("Playout Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# 平均値を計算
mean = sum(scores) / len(scores)
print("平均値: {}".format(mean))  # 0.4869166900896258
# Out:
# 平均値: 0.4869166900896258
